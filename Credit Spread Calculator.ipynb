# %%
import yfinance as yf
import pandas as pd

# %%
spy = yf.Ticker("SPY")
spy.info.get('regularMarketPrice')
# Out:
# 360.91

# %%
ops = spy.options
opt = spy.option_chain(ops[1])
bullish = opt.calls
bearish = opt.puts

# %%
bullish
#trim so just the closest 20 around current price
# Out:
#         contractSymbol       lastTradeDate  strike  lastPrice    bid    ask  \
# 0   SPY201123C00265000 2020-11-06 20:51:11   265.0      86.25  90.82  91.50
# 1   SPY201123C00280000 2020-10-29 19:39:37   280.0      52.97  75.82  76.51
# 2   SPY201123C00290000 2020-11-05 15:13:04   290.0      61.36  65.87  66.51
# 3   SPY201123C00300000 2020-11-06 18:42:19   300.0      50.95  55.88  56.52
# 4   SPY201123C00302000 2020-11-16 05:14:19   302.0      53.46  53.89  54.51
# ..                 ...                 ...     ...        ...    ...    ...
# 87  SPY201123C00410000 2020-11-04 14:39:37   410.0       0.02   0.00   0.01
# 88  SPY201123C00415000 2020-10-22 14:11:37   415.0       0.02   0.00   0.01
# 89  SPY201123C00420000 2020-11-16 05:00:31   420.0       0.01    NaN   0.01
# 90  SPY201123C00430000 2020-10-28 14:28:34   430.0       0.02   0.00   0.01
# 91  SPY201123C00440000 2020-10-30 18:20:10   440.0       0.01   0.00   0.01
#
# ...
